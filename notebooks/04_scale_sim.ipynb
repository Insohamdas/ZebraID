# %% [markdown]
# # 04 — Scale Simulation (1k, 100k, 1M Individual Shards)
#
# This notebook measures query latency (ms), memory footprint (MB), and retrieval accuracy when scaling individual index sizes up to 1 million phantom vectors.

# %%
from zebraid.matching.scale_sim import run_scale_simulation

# Benchmark scale simulation across 1k, 100k, 1M vector database scales
df_scale = run_scale_simulation(scales=[1000, 100000, 1000000])
print(df_scale)
