# %% [markdown]
# # 03 — Z-Hash Compression Trade-off Sweep
#
# This notebook evaluates retrieval accuracy (Rank-1, Rank-5, mAP) across different bit-widths (128b, 256b, 512b) and backends (PCA+Binarization vs. FAISS-PQ).

# %%
from zebraid.models.evaluate_compression import run_compression_sweep

# Run compression sweep across bit sizes 128, 256, 512
df_results = run_compression_sweep(bit_sizes=[128, 256, 512])
print(df_results)
